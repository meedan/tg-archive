# %%
import sqlite3
import pandas as pd

# Replace 'your_database_file.sqlite' with the name of your SQLite database file
database_file = 'data/moigovps/data.sqlite'

# Create a connection to the SQLite database file
connection = sqlite3.connect(database_file)

# Create a cursor object to interact with the database
cursor = connection.cursor()

# Example query to read data from a table in the database
cursor.execute("SELECT * FROM messages")

# Fetch the results and store them in a Pandas DataFrame
data = cursor.fetchall()
df = pd.DataFrame(data)

# Display the DataFrame in the Jupyter Notebook
df
# Out:
#         0        1                    2                    3  \
# 0   45258  message  2023-10-07 04:11:05  2023-10-07 04:11:08
# 1   45259  message  2023-10-07 06:14:32  2023-11-01 07:35:14
# 2   45260  message  2023-10-07 09:01:42  2023-10-07 09:01:45
# 3   45261  message  2023-10-07 09:30:59  2023-10-07 09:31:02
# 4   45262  message  2023-10-07 09:50:53  2023-10-07 09:50:56
# 5   45263  message  2023-10-07 09:54:00  2023-10-07 09:54:03
# 6   45264  message  2023-10-07 12:40:00  2023-10-07 12:40:04
# 7   45265  message  2023-10-07 12:45:28  2023-10-07 12:45:31
# 8   45266  message  2023-10-07 12:58:29  2023-10-07 12:58:32
# 9   45267  message  2023-10-07 13:45:22  2023-10-07 13:54:58
# 10  45269  message  2023-10-07 13:45:23  2023-10-07 13:45:25
# 11  45270  message  2023-10-07 13:45:23  2023-10-07 13:45:25
# 12  45271  message  2023-10-07 13:45:23  2023-10-07 13:45:25
# 13  45272  message  2023-10-07 14:09:18  2023-10-07 14:09:22
# 14  45273  message  2023-10-07 15:35:24  2023-10-07 15:35:27
# 15  45274  message  2023-10-07 15:46:24  2023-10-07 15:46:27
# 16  45275  message  2023-10-07 16:16:18  2023-10-07 16:16:21
# 17  45276  message  2023-10-07 17:28:27  2023-10-07 17:28:31
# 18  45277  message  2023-10-07 17:58:08  2023-10-07 17:58:12
# 19  45278  message  2023-10-07 18:26:50  2023-10-07 18:26:53
#
#                                                     4     5           6  \
# 0   ⭕️ تصريح صحفي:\n\nتتابع الأجهزة الأمنية والشرط...  None  1007352301
# 1   ⭕ المتحدث باسم وزارة الداخلية والأمن الوطني إي...  None  1007352301
# 2   ⭕️📲 للتثبت من الأخبار والتصريحات الصادرة عن وز...  None  1007352301
# 3   ⭕ تصريح صحفي:\n\nتتابع دائرة مباحث التموين توف...  None  1007352301
# 4                                                      None  1007352301
# 5   👈🏻 حذرت من الاحتكار والاستغلال\n\n⭕ المباحث ال...  None  1007352301
# 6   📻 تصريح صحفي للمتحدث باسم وزارة الداخلية والأم...  None  1007352301
# 7   ⭕️ المتحدث باسم وزارة الداخلية والأمن الوطني إ...  None  1007352301
# 8   🔴 تصريح صحفي:\n\nالاحتلال الإسرائيلي شنّ مئات ...  None  1007352301
# 9   📸 صور من انتشار الأجهزة الشرطية على المفترقات ...  None  1007352301
# 10                                                     None  1007352301
# 11                                                     None  1007352301
# 12                                                     None  1007352301
# 13  ⭕ عزيزي المواطن.. الإجراءات الواجب اتخاذها في ...  None  1007352301
# 14  ⭕️ تصريح صحفي:\n\nطائرات الاحتلال تدمر برج فلس...  None  1007352301
# 15  ⭕ توجيهات مهمة للمواطنين ونشطاء مواقع التواصل ...  None  1007352301
# 16  ⭕️ تصريح صحفي:\n\nطائرات الاحتلال تدمر عمارة ا...  None  1007352301
# 17  ⭕ إنفوجراف | إرشادات السلامة للتخفيف من أضرار ...  None  1007352301
# 18  ⭕️ تصريح صحفي:\n\nطائرات الاحتلال تدمر منزلين ...  None  1007352301
# 19  ⭕️ تصريح صحفي:\n\nطواقم الدفاع المدني والخدمات...  None  1007352301
#
#           7
# 0       NaN
# 1       NaN
# 2   45260.0
# 3       NaN
# 4   45262.0
# 5   45263.0
# 6   45264.0
# 7       NaN
# 8       NaN
# 9   45267.0
# 10  45269.0
# 11  45270.0
# 12  45271.0
# 13  45272.0
# 14      NaN
# 15  45274.0
# 16      NaN
# 17  45276.0
# 18      NaN
# 19      NaN

# %%
# You can now work with the 'data' variable, which contains the results of the query

# Close the cursor and connection when you're done
cursor.close()
connection.close()
