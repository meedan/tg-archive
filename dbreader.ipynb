# %%
import sqlite3
import pandas as pd

# Replace 'your_database_file.sqlite' with the name of your SQLite database file
database_file = 'data/osama1984osama/data.sqlite'

# Create a connection to the SQLite database file
connection = sqlite3.connect(database_file)

# Create a cursor object to interact with the database
cursor = connection.cursor()

# Example query to read data from a table in the database
cursor.execute("SELECT * FROM messages")

# Fetch the results and store them in a Pandas DataFrame
data = cursor.fetchall()
df = pd.DataFrame(data)

# Display the DataFrame in the Jupyter Notebook
df
# Out:
#         0        1                    2                    3  \
# 0   46343  message  2023-10-03 06:12:27                 None
# 1   46344  message  2023-10-03 06:12:56                 None
# 2   46345  message  2023-10-03 06:13:08                 None
# 3   46346  message  2023-10-03 06:13:44                 None
# 4   46347  message  2023-10-03 06:14:10                 None
# 5   46348  message  2023-10-03 06:14:51  2023-10-03 06:31:48
# 6   46349  message  2023-10-03 06:15:12                 None
# 7   46350  message  2023-10-03 06:31:48  2023-10-03 07:51:02
# 8   46351  message  2023-10-03 09:55:57                 None
# 9   46352  message  2023-10-03 09:57:38                 None
# 10  46353  message  2023-10-03 10:19:59                 None
# 11  46354  message  2023-10-03 10:20:00                 None
# 12  46355  message  2023-10-03 10:20:00                 None
# 13  46356  message  2023-10-03 10:20:00                 None
# 14  46357  message  2023-10-03 10:20:01                 None
# 15  46358  message  2023-10-03 10:20:01                 None
# 16  46359  message  2023-10-03 10:20:01                 None
# 17  46360  message  2023-10-03 10:20:01                 None
# 18  46361  message  2023-10-03 10:20:01                 None
# 19  46362  message  2023-10-03 10:20:01                 None
#
#                                                     4     5           6  \
# 0   ⭕️ شاهد| قوات الاحتلال تمنع المقدسيين من دخول ...  None  1434753001
# 1   🌦️حالة الطقس: أجواء خريفية لطيفة في معظم المنا...  None  1434753001
# 2   💰أسعار صرف العملات مقابل الشيكل اليوم الثلاثاء...  None  1434753001
# 3   الهلال الأحمر: إصابة 7 مواطنين خلال مواجهات مع...  None  1434753001
# 4   المقاومة في قطاع غزة تطلق صواريخ تجريبية باتجا...  None  1434753001
# 5   سرايا القدس: سرايا القدس تنفذ الآن في أحد مواق...  None  1434753001
# 6   مصادر مقدسية: أكثر من 150 مستوطنًا اقتحموا الم...  None  1434753001
# 7   *إذاعة الجيش الإسرائيلي:*\nتفعيل صفارات الإنذا...  None  1434753001
# 8                          وفاة طفل في حادث سير برفح.  None  1434753001
# 9   مرور غزة : وفاة الطفل (ياسين محمد موسى أبو جزر...  None  1434753001
# 10                مزارعو غزة يبدأون قطف محصول "البلح"  None  1434753001
# 11                                                     None  1434753001
# 12                                                     None  1434753001
# 13                                                     None  1434753001
# 14                                                     None  1434753001
# 15                                                     None  1434753001
# 16                                                     None  1434753001
# 17                                                     None  1434753001
# 18                                                     None  1434753001
# 19                                                     None  1434753001
#
#           7
# 0   46343.0
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11  46354.0
# 12  46355.0
# 13  46356.0
# 14  46357.0
# 15  46358.0
# 16  46359.0
# 17  46360.0
# 18  46361.0
# 19  46362.0

# %%
# You can now work with the 'data' variable, which contains the results of the query

# Close the cursor and connection when you're done
cursor.close()
connection.close()
